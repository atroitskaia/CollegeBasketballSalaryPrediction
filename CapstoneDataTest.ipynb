# %%
pip install nba_api
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 7.3 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 kB 15.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.7.4
#     Uninstalling certifi-2024.7.4:
#       Successfully uninstalled certifi-2024.7.4
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from nba_api.stats.endpoints import drafthistory
from nba_api.stats.endpoints import playercareerstats

import pandas as pd

# Fetch the NBA Draft History data
draft_history = drafthistory.DraftHistory()
draft_history_df = draft_history.get_data_frames()[0]

# Display the first few rows of the draft history data
draft_history_df.head()
# Out:
#    PERSON_ID         PLAYER_NAME SEASON  ROUND_NUMBER  ROUND_PICK  \
# 0    1642258  Zaccharie Risacher   2024             1           1
# 1    1642259      Alexandre Sarr   2024             1           2
# 2    1642263       Reed Sheppard   2024             1           3
# 3    1642264      Stephon Castle   2024             1           4
# 4    1641842   Ronald Holland II   2024             1           5
#
#    OVERALL_PICK DRAFT_TYPE     TEAM_ID    TEAM_CITY TEAM_NAME  \
# 0             1      Draft  1610612737      Atlanta     Hawks
# 1             2      Draft  1610612764   Washington   Wizards
# 2             3      Draft  1610612745      Houston   Rockets
# 3             4      Draft  1610612759  San Antonio     Spurs
# 4             5      Draft  1610612765      Detroit   Pistons
#
#   TEAM_ABBREVIATION                ORGANIZATION   ORGANIZATION_TYPE  \
# 0               ATL           JL Bourg (France)     Other Team/Club
# ...
